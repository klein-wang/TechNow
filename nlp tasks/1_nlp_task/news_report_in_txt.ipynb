# %% [markdown]
# #### Reading News

# %%
# loading packages (pip/pip3 list for new packages)
import re
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import spacy
# python3 -m spacy download en_core_web_trf
nlp = spacy.load('en_core_web_trf') # Loading Spacy's English model | run python/python3 -m spacy download en_core_web_trf to download first
# try 'en_core_web_md' or 'en_core_web_lg' for higher accuracy

# %% [markdown]
# ##### Task1: reading article by line

# %%
file_path = "sample.txt"

try:
    with open(file_path, 'r', encoding='utf-8') as file:
        articles = file.readlines()[:]  # Change the number to adjust the sample size
        # for article in articles:
        #     print(article)
except FileNotFoundError:
    print(f"File '{file_path}' not found.")

print(f'{len(articles)} articles have been imported.')
# Out:
# 1870 articles have been imported.

# %% [markdown]
# ##### Task2: count articles which contain 'gold', 'silver'

# %%
# Find 'gold' & 'silver' and count articles
def string_matcher(article):
    article_lower = article.lower()
    contains_gold = "gold" in article_lower
    contains_silver = "silver" in article_lower
    return contains_gold, contains_silver

gold_count = 0
silver_count = 0

for i, text in enumerate(articles):
    contains_gold, contains_silver = string_matcher(text)
    # print(f'Article{i} contains gold: {contains_gold} and silver: {contains_silver}.')
    
    if contains_gold:
        gold_count += 1
        # print(text)
    if contains_silver:
        silver_count += 1
        # print(text)
print(f'Total articles containing gold: {gold_count}')
print(f'Total articles containing silver: {silver_count}')
# Out:
# Article0 contains gold: True and silver: False.
# Article1 contains gold: True and silver: False.
# Article2 contains gold: True and silver: False.
# Article3 contains gold: True and silver: False.
# Article4 contains gold: True and silver: False.
# Article5 contains gold: True and silver: False.
# Article6 contains gold: True and silver: False.
# Article7 contains gold: True and silver: False.
# Article8 contains gold: True and silver: False.
# Article9 contains gold: True and silver: False.
# Article10 contains gold: True and silver: False.
# Article11 contains gold: True and silver: False.
# Article12 contains gold: True and silver: False.
# Article13 contains gold: True and silver: False.
# Article14 contains gold: True and silver: False.
# Article15 contains gold: True and silver: False.
# Article16 contains gold: True and silver: False.
# Article17 contains gold: True and silver: False.
# Article18 contains gold: True and silver: False.
# Article19 contains gold: True and silver: False.
# Article20 contains gold: True and silver: False.
# Article21 contains gold: True and silver: False.
# Article22 contains gold: False and silver: True.
# Article23 contains gold: True and silver: False.
# Article24 contains gold: True and silver: False.
# Article25 contains gold: True and silver: False.
# Article26 contains gold: True and silver: False.
# Article27 contains gold: True and silver: False.
# Article28 contains gold: True and silver: False.
# Article29 contains gold: True and silver: False.
# Article30 contains gold: False and silver: False.
# Article31 contains gold: True and silver: False.
# Article32 contains gold: True and silver: False.
# Article33 contains gold: True and silver: False.
# Article34 contains gold: True and silver: False.
# Article35 contains gold: True and silver: False.
# Article36 contains gold: False and silver: True.
# Article37 contains gold: True and silver: False.
# Article38 contains gold: True and silver: False.
# Article39 contains gold: True and silver: False.
# Article40 contains gold: True and silver: False.
# Article41 contains gold: True and silver: False.
# Article42 contains gold: True and silver: False.
# Article43 contains gold: True and silver: False.
# Article44 contains gold: True and silver: False.
# Article45 contains gold: True and silver: False.
# Article46 contains gold: True and silver: False.
# Article47 contains gold: True and silver: False.
# Article48 contains gold: True and silver: False.
# Article49 contains gold: True and silver: False.
# Article50 contains gold: False and silver: True.
# Article51 contains gold: True and silver: False.
# Article52 contains gold: True and silver: False.
# Article53 contains gold: True and silver: True.
# Article54 contains gold: True and silver: False.
# Article55 contains gold: True and silver: False.
# Article56 contains gold: True and silver: False.
# Article57 contains gold: True and silver: False.
# Article58 contains gold: False and silver: False.
# Article59 contains gold: False and silver: False.
# Article60 contains gold: True and silver: False.
# Article61 contains gold: False and silver: False.
# Article62 contains gold: False and silver: False.
# Article63 contains gold: False and silver: False.
# Article64 contains gold: False and silver: False.
# Article65 contains gold: False and silver: False.
# Article66 contains gold: False and silver: False.
# Article67 contains gold: False and silver: False.
# Article68 contains gold: False and silver: False.
# Article69 contains gold: True and silver: False.
# Article70 contains gold: True and silver: False.
# Article71 contains gold: True and silver: False.
# Article72 contains gold: True and silver: False.
# Article73 contains gold: True and silver: False.
# Article74 contains gold: False and silver: True.
# Article75 contains gold: True and silver: False.
# Article76 contains gold: True and silver: False.
# Article77 contains gold: True and silver: False.
# Article78 contains gold: True and silver: False.
# Article79 contains gold: True and silver: False.
# Article80 contains gold: True and silver: False.
# Article81 contains gold: True and silver: False.
# Article82 contains gold: True and silver: False.
# Article83 contains gold: True and silver: False.
# Article84 contains gold: True and silver: False.
# Article85 contains gold: True and silver: False.
# Article86 contains gold: False and silver: False.
# Article87 contains gold: False and silver: False.
# Article88 contains gold: False and silver: True.
# Article89 contains gold: True and silver: False.
# Article90 contains gold: False and silver: False.
# Article91 contains gold: False and silver: False.
# Article92 contains gold: True and silver: False.
# Article93 contains gold: True and silver: False.
# Article94 contains gold: False and silver: True.
# Article95 contains gold: True and silver: False.
# Article96 contains gold: True and silver: False.
# Article97 contains gold: True and silver: False.
# Article98 contains gold: True and silver: False.
# Article99 contains gold: True and silver: False.
# Article100 contains gold: True and silver: False.
# Article101 contains gold: True and silver: False.
# Article102 contains gold: True and silver: False.
# Article103 contains gold: True and silver: False.
# Article104 contains gold: True and silver: False.
# Article105 contains gold: True and silver: False.
# Article106 contains gold: True and silver: False.
# Article107 contains gold: True and silver: True.
# Article108 contains gold: True and silver: False.
# Article109 contains gold: True and silver: False.
# Article110 contains gold: True and silver: False.
# Article111 contains gold: True and silver: False.
# Article112 contains gold: False and silver: False.
# Article113 contains gold: False and silver: False.
# Article114 contains gold: False and silver: True.
# Article115 contains gold: True and silver: False.
# Article116 contains gold: True and silver: False.
# Article117 contains gold: True and silver: False.
# Article118 contains gold: True and silver: False.
# Article119 contains gold: False and silver: False.
# Article120 contains gold: False and silver: False.
# Article121 contains gold: False and silver: False.
# Article122 contains gold: False and silver: False.
# Article123 contains gold: True and silver: False.
# Article124 contains gold: True and silver: False.
# Article125 contains gold: True and silver: False.
# Article126 contains gold: True and silver: False.
# Article127 contains gold: True and silver: False.
# Article128 contains gold: True and silver: False.
# Article129 contains gold: True and silver: False.
# Article130 contains gold: True and silver: True.
# Article131 contains gold: True and silver: False.
# Article132 contains gold: True and silver: False.
# Article133 contains gold: True and silver: False.
# Article134 contains gold: True and silver: True.
# Article135 contains gold: True and silver: False.
# Article136 contains gold: True and silver: False.
# Article137 contains gold: True and silver: False.
# Article138 contains gold: True and silver: False.
# Article139 contains gold: False and silver: True.
# Article140 contains gold: True and silver: False.
# Article141 contains gold: True and silver: True.
# Article142 contains gold: True and silver: False.
# Article143 contains gold: True and silver: False.
# Article144 contains gold: True and silver: False.
# Article145 contains gold: True and silver: False.
# Article146 contains gold: True and silver: False.
# Article147 contains gold: True and silver: False.
# Article148 contains gold: True and silver: True.
# Article149 contains gold: True and silver: False.
# Article150 contains gold: False and silver: False.
# Article151 contains gold: False and silver: False.
# Article152 contains gold: False and silver: False.
# Article153 contains gold: False and silver: False.
# Article154 contains gold: True and silver: False.
# Article155 contains gold: False and silver: False.
# Article156 contains gold: False and silver: False.
# Article157 contains gold: False and silver: False.
# Article158 contains gold: False and silver: False.
# Article159 contains gold: True and silver: False.
# Article160 contains gold: True and silver: False.
# Article161 contains gold: True and silver: False.
# Article162 contains gold: True and silver: False.
# Article163 contains gold: True and silver: True.
# Article164 contains gold: True and silver: False.
# Article165 contains gold: True and silver: False.
# Article166 contains gold: True and silver: False.
# Article167 contains gold: True and silver: False.
# Article168 contains gold: True and silver: False.
# Article169 contains gold: True and silver: False.
# Article170 contains gold: True and silver: False.
# Article171 contains gold: True and silver: False.
# Article172 contains gold: True and silver: False.
# Article173 contains gold: True and silver: False.
# Article174 contains gold: True and silver: False.
# Article175 contains gold: True and silver: False.
# Article176 contains gold: True and silver: False.
# Article177 contains gold: True and silver: False.
# Article178 contains gold: True and silver: False.
# Article179 contains gold: True and silver: False.
# Article180 contains gold: True and silver: False.
# Article181 contains gold: True and silver: False.
# Article182 contains gold: True and silver: False.
# Article183 contains gold: True and silver: False.
# Article184 contains gold: True and silver: False.
# Article185 contains gold: False and silver: True.
# Article186 contains gold: True and silver: False.
# Article187 contains gold: True and silver: False.
# Article188 contains gold: True and silver: False.
# Article189 contains gold: True and silver: False.
# Article190 contains gold: True and silver: False.
# Article191 contains gold: True and silver: False.
# Article192 contains gold: False and silver: True.
# Article193 contains gold: True and silver: False.
# Article194 contains gold: True and silver: False.
# Article195 contains gold: True and silver: False.
# Article196 contains gold: True and silver: False.
# Article197 contains gold: True and silver: True.
# Article198 contains gold: False and silver: True.
# Article199 contains gold: True and silver: True.
# Article200 contains gold: False and silver: True.
# Article201 contains gold: True and silver: False.
# Article202 contains gold: True and silver: False.
# Article203 contains gold: True and silver: False.
# Article204 contains gold: True and silver: False.
# Article205 contains gold: True and silver: False.
# Article206 contains gold: True and silver: False.
# Article207 contains gold: True and silver: False.
# Article208 contains gold: True and silver: False.
# Article209 contains gold: True and silver: False.
# Article210 contains gold: True and silver: False.
# Article211 contains gold: True and silver: False.
# Article212 contains gold: True and silver: False.
# Article213 contains gold: True and silver: False.
# Article214 contains gold: True and silver: False.
# Article215 contains gold: True and silver: False.
# Article216 contains gold: False and silver: True.
# Article217 contains gold: True and silver: False.
# Article218 contains gold: True and silver: False.
# Article219 contains gold: True and silver: False.
# Article220 contains gold: True and silver: False.
# Article221 contains gold: True and silver: False.
# Article222 contains gold: True and silver: False.
# Article223 contains gold: True and silver: True.
# Article224 contains gold: True and silver: False.
# Article225 contains gold: True and silver: False.
# Article226 contains gold: True and silver: True.
# Article227 contains gold: False and silver: True.
# Article228 contains gold: False and silver: False.
# Article229 contains gold: True and silver: False.
# Article230 contains gold: True and silver: False.
# Article231 contains gold: False and silver: True.
# Article232 contains gold: True and silver: False.
# Article233 contains gold: True and silver: False.
# Article234 contains gold: True and silver: False.
# Article235 contains gold: True and silver: False.
# Article236 contains gold: True and silver: False.
# Article237 contains gold: True and silver: False.
# Article238 contains gold: True and silver: False.
# Article239 contains gold: True and silver: False.
# Article240 contains gold: True and silver: False.
# Article241 contains gold: True and silver: True.
# Article242 contains gold: True and silver: False.
# Article243 contains gold: True and silver: False.
# Article244 contains gold: False and silver: False.
# Article245 contains gold: False and silver: True.
# Article246 contains gold: True and silver: False.
# Article247 contains gold: False and silver: True.
# Article248 contains gold: True and silver: False.
# Article249 contains gold: True and silver: True.
# Article250 contains gold: True and silver: False.
# Article251 contains gold: True and silver: False.
# Article252 contains gold: True and silver: False.
# Article253 contains gold: True and silver: True.
# Article254 contains gold: True and silver: False.
# Article255 contains gold: True and silver: False.
# Article256 contains gold: True and silver: False.
# Article257 contains gold: True and silver: False.
# Article258 contains gold: True and silver: False.
# Article259 contains gold: False and silver: False.
# Article260 contains gold: True and silver: False.
# Article261 contains gold: True and silver: False.
# Article262 contains gold: True and silver: True.
# Article263 contains gold: True and silver: False.
# Article264 contains gold: True and silver: False.
# Article265 contains gold: True and silver: False.
# Article266 contains gold: True and silver: False.
# Article267 contains gold: True and silver: False.
# Article268 contains gold: True and silver: False.
# Article269 contains gold: True and silver: False.
# Article270 contains gold: True and silver: False.
# Article271 contains gold: True and silver: False.
# Article272 contains gold: True and silver: False.
# Article273 contains gold: True and silver: False.
# Article274 contains gold: True and silver: False.
# Article275 contains gold: True and silver: False.
# Article276 contains gold: True and silver: False.
# Article277 contains gold: True and silver: False.
# Article278 contains gold: True and silver: False.
# Article279 contains gold: True and silver: False.
# Article280 contains gold: True and silver: True.
# Article281 contains gold: True and silver: False.
# Article282 contains gold: True and silver: False.
# Article283 contains gold: True and silver: False.
# Article284 contains gold: True and silver: False.
# Article285 contains gold: True and silver: False.
# Article286 contains gold: False and silver: True.
# Article287 contains gold: True and silver: False.
# Article288 contains gold: True and silver: False.
# Article289 contains gold: True and silver: False.
# Article290 contains gold: True and silver: False.
# Article291 contains gold: True and silver: False.
# Article292 contains gold: True and silver: False.
# Article293 contains gold: True and silver: False.
# Article294 contains gold: True and silver: False.
# Article295 contains gold: True and silver: False.
# Article296 contains gold: True and silver: False.
# Article297 contains gold: True and silver: False.
# Article298 contains gold: True and silver: False.
# Article299 contains gold: True and silver: False.
# Article300 contains gold: True and silver: False.
# Article301 contains gold: True and silver: False.
# Article302 contains gold: True and silver: False.
# Article303 contains gold: True and silver: False.
# Article304 contains gold: True and silver: False.
# Article305 contains gold: True and silver: True.
# Article306 contains gold: True and silver: False.
# Article307 contains gold: True and silver: False.
# Article308 contains gold: True and silver: False.
# Article309 contains gold: True and silver: False.
# Article310 contains gold: True and silver: False.
# Article311 contains gold: True and silver: False.
# Article312 contains gold: True and silver: False.
# Article313 contains gold: True and silver: False.
# Article314 contains gold: True and silver: False.
# Article315 contains gold: True and silver: False.
# Article316 contains gold: True and silver: False.
# Article317 contains gold: True and silver: False.
# Article318 contains gold: True and silver: False.
# Article319 contains gold: True and silver: False.
# Article320 contains gold: False and silver: False.
# Article321 contains gold: True and silver: False.
# Article322 contains gold: True and silver: False.
# Article323 contains gold: True and silver: False.
# Article324 contains gold: True and silver: False.
# Article325 contains gold: True and silver: False.
# Article326 contains gold: True and silver: False.
# Article327 contains gold: True and silver: False.
# Article328 contains gold: True and silver: False.
# Article329 contains gold: True and silver: False.
# Article330 contains gold: True and silver: False.
# Article331 contains gold: True and silver: False.
# Article332 contains gold: True and silver: False.
# Article333 contains gold: True and silver: False.
# Article334 contains gold: True and silver: True.
# Article335 contains gold: False and silver: True.
# Article336 contains gold: True and silver: False.
# Article337 contains gold: True and silver: False.
# Article338 contains gold: True and silver: False.
# Article339 contains gold: True and silver: False.
# Article340 contains gold: True and silver: False.
# Article341 contains gold: True and silver: False.
# Article342 contains gold: True and silver: False.
# Article343 contains gold: True and silver: False.
# Article344 contains gold: False and silver: True.
# Article345 contains gold: False and silver: False.
# Article346 contains gold: False and silver: False.
# Article347 contains gold: False and silver: False.
# Article348 contains gold: False and silver: False.
# Article349 contains gold: False and silver: False.
# Article350 contains gold: False and silver: False.
# Article351 contains gold: False and silver: False.
# Article352 contains gold: False and silver: False.
# Article353 contains gold: False and silver: False.
# Article354 contains gold: False and silver: False.
# Article355 contains gold: True and silver: False.
# Article356 contains gold: False and silver: False.
# Article357 contains gold: False and silver: False.
# Article358 contains gold: False and silver: False.
# Article359 contains gold: True and silver: False.
# Article360 contains gold: True and silver: False.
# Article361 contains gold: True and silver: False.
# Article362 contains gold: True and silver: True.
# Article363 contains gold: True and silver: False.
# Article364 contains gold: False and silver: True.
# Article365 contains gold: True and silver: False.
# Article366 contains gold: True and silver: False.
# Article367 contains gold: True and silver: False.
# Article368 contains gold: True and silver: False.
# Article369 contains gold: True and silver: False.
# Article370 contains gold: True and silver: False.
# Article371 contains gold: True and silver: False.
# Article372 contains gold: True and silver: False.
# Article373 contains gold: False and silver: False.
# Article374 contains gold: False and silver: False.
# Article375 contains gold: False and silver: False.
# Article376 contains gold: False and silver: False.
# Article377 contains gold: False and silver: False.
# Article378 contains gold: False and silver: False.
# Article379 contains gold: False and silver: False.
# Article380 contains gold: False and silver: False.
# Article381 contains gold: False and silver: False.
# Article382 contains gold: False and silver: False.
# Article383 contains gold: True and silver: False.
# Article384 contains gold: True and silver: False.
# Article385 contains gold: True and silver: False.
# Article386 contains gold: True and silver: False.
# Article387 contains gold: True and silver: False.
# Article388 contains gold: True and silver: False.
# Article389 contains gold: True and silver: False.
# Article390 contains gold: False and silver: True.
# Article391 contains gold: True and silver: False.
# Article392 contains gold: False and silver: True.
# Article393 contains gold: True and silver: False.
# Article394 contains gold: False and silver: True.
# Article395 contains gold: False and silver: False.
# Article396 contains gold: True and silver: False.
# Article397 contains gold: True and silver: False.
# Article398 contains gold: True and silver: True.
# Article399 contains gold: False and silver: False.
# Article400 contains gold: True and silver: False.
# Article401 contains gold: True and silver: True.
# Article402 contains gold: False and silver: True.
# Article403 contains gold: True and silver: False.
# Article404 contains gold: True and silver: True.
# Article405 contains gold: True and silver: False.
# Article406 contains gold: True and silver: False.
# Article407 contains gold: True and silver: False.
# Article408 contains gold: True and silver: False.
# Article409 contains gold: True and silver: False.
# Article410 contains gold: True and silver: False.
# Article411 contains gold: True and silver: False.
# Article412 contains gold: True and silver: False.
# Article413 contains gold: True and silver: False.
# Article414 contains gold: True and silver: False.
# Article415 contains gold: True and silver: False.
# Article416 contains gold: True and silver: False.
# Article417 contains gold: False and silver: True.
# Article418 contains gold: True and silver: False.
# Article419 contains gold: True and silver: False.
# Article420 contains gold: True and silver: False.
# Article421 contains gold: True and silver: False.
# Article422 contains gold: True and silver: False.
# Article423 contains gold: True and silver: False.
# Article424 contains gold: True and silver: False.
# Article425 contains gold: True and silver: False.
# Article426 contains gold: True and silver: False.
# Article427 contains gold: True and silver: False.
# Article428 contains gold: True and silver: True.
# Article429 contains gold: True and silver: False.
# Article430 contains gold: True and silver: False.
# Article431 contains gold: False and silver: True.
# Article432 contains gold: True and silver: False.
# Article433 contains gold: True and silver: False.
# Article434 contains gold: True and silver: False.
# Article435 contains gold: True and silver: False.
# Article436 contains gold: False and silver: True.
# Article437 contains gold: True and silver: False.
# Article438 contains gold: True and silver: False.
# Article439 contains gold: False and silver: False.
# Article440 contains gold: False and silver: False.
# Article441 contains gold: False and silver: False.
# Article442 contains gold: False and silver: False.
# Article443 contains gold: False and silver: False.
# Article444 contains gold: False and silver: False.
# Article445 contains gold: False and silver: False.
# Article446 contains gold: False and silver: False.
# Article447 contains gold: False and silver: False.
# Article448 contains gold: False and silver: False.
# Article449 contains gold: False and silver: False.
# Article450 contains gold: False and silver: False.
# Article451 contains gold: False and silver: False.
# Article452 contains gold: False and silver: False.
# Article453 contains gold: False and silver: False.
# Article454 contains gold: False and silver: False.
# Article455 contains gold: False and silver: False.
# Article456 contains gold: False and silver: False.
# Article457 contains gold: False and silver: False.
# Article458 contains gold: False and silver: False.
# Article459 contains gold: False and silver: False.
# Article460 contains gold: False and silver: False.
# Article461 contains gold: False and silver: False.
# Article462 contains gold: False and silver: False.
# Article463 contains gold: True and silver: False.
# Article464 contains gold: False and silver: False.
# Article465 contains gold: False and silver: False.
# Article466 contains gold: False and silver: False.
# Article467 contains gold: False and silver: False.
# Article468 contains gold: False and silver: False.
# Article469 contains gold: False and silver: False.
# Article470 contains gold: False and silver: False.
# Article471 contains gold: False and silver: False.
# Article472 contains gold: False and silver: False.
# Article473 contains gold: False and silver: False.
# Article474 contains gold: False and silver: False.
# Article475 contains gold: False and silver: False.
# Article476 contains gold: False and silver: False.
# Article477 contains gold: False and silver: False.
# Article478 contains gold: False and silver: False.
# Article479 contains gold: False and silver: False.
# Article480 contains gold: False and silver: False.
# Article481 contains gold: False and silver: False.
# Article482 contains gold: False and silver: False.
# Article483 contains gold: False and silver: False.
# Article484 contains gold: False and silver: False.
# Article485 contains gold: False and silver: False.
# Article486 contains gold: False and silver: False.
# Article487 contains gold: False and silver: False.
# Article488 contains gold: False and silver: False.
# Article489 contains gold: False and silver: False.
# Article490 contains gold: False and silver: False.
# Article491 contains gold: False and silver: False.
# Article492 contains gold: False and silver: False.
# Article493 contains gold: False and silver: False.
# Article494 contains gold: False and silver: False.
# Article495 contains gold: False and silver: False.
# Article496 contains gold: False and silver: False.
# Article497 contains gold: False and silver: False.
# Article498 contains gold: False and silver: False.
# Article499 contains gold: False and silver: False.
# Article500 contains gold: False and silver: False.
# Article501 contains gold: False and silver: False.
# Article502 contains gold: False and silver: False.
# Article503 contains gold: False and silver: False.
# Article504 contains gold: False and silver: False.
# Article505 contains gold: False and silver: False.
# Article506 contains gold: False and silver: False.
# Article507 contains gold: False and silver: False.
# Article508 contains gold: False and silver: False.
# Article509 contains gold: False and silver: False.
# Article510 contains gold: False and silver: False.
# Article511 contains gold: False and silver: False.
# Article512 contains gold: False and silver: False.
# Article513 contains gold: False and silver: False.
# Article514 contains gold: False and silver: False.
# Article515 contains gold: False and silver: False.
# Article516 contains gold: False and silver: False.
# Article517 contains gold: False and silver: False.
# Article518 contains gold: False and silver: False.
# Article519 contains gold: False and silver: False.
# Article520 contains gold: False and silver: False.
# Article521 contains gold: False and silver: False.
# Article522 contains gold: False and silver: False.
# Article523 contains gold: False and silver: False.
# Article524 contains gold: False and silver: False.
# Article525 contains gold: False and silver: False.
# Article526 contains gold: False and silver: False.
# Article527 contains gold: False and silver: False.
# Article528 contains gold: True and silver: False.
# Article529 contains gold: False and silver: False.
# Article530 contains gold: False and silver: False.
# Article531 contains gold: False and silver: False.
# Article532 contains gold: False and silver: False.
# Article533 contains gold: False and silver: False.
# Article534 contains gold: False and silver: False.
# Article535 contains gold: False and silver: False.
# Article536 contains gold: False and silver: False.
# Article537 contains gold: False and silver: False.
# Article538 contains gold: False and silver: False.
# Article539 contains gold: False and silver: False.
# Article540 contains gold: False and silver: False.
# Article541 contains gold: False and silver: False.
# Article542 contains gold: False and silver: False.
# Article543 contains gold: False and silver: False.
# Article544 contains gold: False and silver: False.
# Article545 contains gold: False and silver: False.
# Article546 contains gold: False and silver: False.
# Article547 contains gold: False and silver: False.
# Article548 contains gold: False and silver: False.
# Article549 contains gold: False and silver: False.
# Article550 contains gold: False and silver: False.
# Article551 contains gold: False and silver: False.
# Article552 contains gold: False and silver: False.
# Article553 contains gold: False and silver: False.
# Article554 contains gold: False and silver: False.
# Article555 contains gold: False and silver: False.
# Article556 contains gold: False and silver: False.
# Article557 contains gold: False and silver: False.
# Article558 contains gold: False and silver: False.
# Article559 contains gold: False and silver: False.
# Article560 contains gold: False and silver: False.
# Article561 contains gold: False and silver: False.
# Article562 contains gold: False and silver: False.
# Article563 contains gold: False and silver: False.
# Article564 contains gold: False and silver: False.
# Article565 contains gold: False and silver: False.
# Article566 contains gold: False and silver: False.
# Article567 contains gold: False and silver: False.
# Article568 contains gold: False and silver: False.
# Article569 contains gold: False and silver: False.
# Article570 contains gold: False and silver: False.
# Article571 contains gold: False and silver: False.
# Article572 contains gold: False and silver: False.
# Article573 contains gold: False and silver: False.
# Article574 contains gold: False and silver: False.
# Article575 contains gold: False and silver: False.
# Article576 contains gold: False and silver: False.
# Article577 contains gold: False and silver: False.
# Article578 contains gold: False and silver: False.
# Article579 contains gold: False and silver: False.
# Article580 contains gold: False and silver: False.
# Article581 contains gold: False and silver: False.
# Article582 contains gold: False and silver: False.
# Article583 contains gold: False and silver: False.
# Article584 contains gold: False and silver: False.
# Article585 contains gold: False and silver: False.
# Article586 contains gold: False and silver: False.
# Article587 contains gold: False and silver: False.
# Article588 contains gold: False and silver: False.
# Article589 contains gold: False and silver: False.
# Article590 contains gold: False and silver: False.
# Article591 contains gold: False and silver: False.
# Article592 contains gold: False and silver: False.
# Article593 contains gold: False and silver: False.
# Article594 contains gold: False and silver: False.
# Article595 contains gold: False and silver: False.
# Article596 contains gold: False and silver: False.
# Article597 contains gold: False and silver: False.
# Article598 contains gold: False and silver: False.
# Article599 contains gold: False and silver: False.
# Article600 contains gold: False and silver: False.
# Article601 contains gold: False and silver: False.
# Article602 contains gold: False and silver: False.
# Article603 contains gold: False and silver: False.
# Article604 contains gold: False and silver: False.
# Article605 contains gold: False and silver: False.
# Article606 contains gold: False and silver: False.
# Article607 contains gold: False and silver: False.
# Article608 contains gold: False and silver: False.
# Article609 contains gold: False and silver: False.
# Article610 contains gold: False and silver: False.
# Article611 contains gold: False and silver: False.
# Article612 contains gold: False and silver: False.
# Article613 contains gold: False and silver: False.
# Article614 contains gold: False and silver: False.
# Article615 contains gold: False and silver: False.
# Article616 contains gold: False and silver: False.
# Article617 contains gold: False and silver: False.
# Article618 contains gold: False and silver: False.
# Article619 contains gold: False and silver: False.
# Article620 contains gold: False and silver: False.
# Article621 contains gold: False and silver: False.
# Article622 contains gold: False and silver: False.
# Article623 contains gold: False and silver: False.
# Article624 contains gold: False and silver: False.
# Article625 contains gold: False and silver: False.
# Article626 contains gold: False and silver: False.
# Article627 contains gold: False and silver: False.
# Article628 contains gold: False and silver: False.
# Article629 contains gold: False and silver: False.
# Article630 contains gold: False and silver: False.
# Article631 contains gold: False and silver: False.
# Article632 contains gold: False and silver: False.
# Article633 contains gold: False and silver: False.
# Article634 contains gold: False and silver: False.
# Article635 contains gold: False and silver: False.
# Article636 contains gold: False and silver: False.
# Article637 contains gold: False and silver: False.
# Article638 contains gold: False and silver: False.
# Article639 contains gold: False and silver: False.
# Article640 contains gold: False and silver: False.
# Article641 contains gold: False and silver: False.
# Article642 contains gold: False and silver: False.
# Article643 contains gold: False and silver: False.
# Article644 contains gold: False and silver: False.
# Article645 contains gold: False and silver: False.
# Article646 contains gold: False and silver: False.
# Article647 contains gold: False and silver: False.
# Article648 contains gold: False and silver: False.
# Article649 contains gold: False and silver: False.
# Article650 contains gold: False and silver: False.
# Article651 contains gold: False and silver: False.
# Article652 contains gold: False and silver: False.
# Article653 contains gold: False and silver: False.
# Article654 contains gold: False and silver: False.
# Article655 contains gold: False and silver: False.
# Article656 contains gold: False and silver: False.
# Article657 contains gold: False and silver: False.
# Article658 contains gold: False and silver: False.
# Article659 contains gold: False and silver: False.
# Article660 contains gold: False and silver: False.
# Article661 contains gold: False and silver: False.
# Article662 contains gold: False and silver: False.
# Article663 contains gold: False and silver: False.
# Article664 contains gold: False and silver: False.
# Article665 contains gold: False and silver: False.
# Article666 contains gold: False and silver: False.
# Article667 contains gold: False and silver: False.
# Article668 contains gold: False and silver: False.
# Article669 contains gold: False and silver: False.
# Article670 contains gold: False and silver: False.
# Article671 contains gold: False and silver: False.
# Article672 contains gold: False and silver: False.
# Article673 contains gold: False and silver: False.
# Article674 contains gold: False and silver: False.
# Article675 contains gold: False and silver: False.
# Article676 contains gold: False and silver: False.
# Article677 contains gold: False and silver: False.
# Article678 contains gold: False and silver: False.
# Article679 contains gold: False and silver: False.
# Article680 contains gold: False and silver: False.
# Article681 contains gold: False and silver: False.
# Article682 contains gold: False and silver: False.
# Article683 contains gold: False and silver: False.
# Article684 contains gold: False and silver: False.
# Article685 contains gold: False and silver: False.
# Article686 contains gold: False and silver: False.
# Article687 contains gold: False and silver: False.
# Article688 contains gold: False and silver: False.
# Article689 contains gold: False and silver: False.
# Article690 contains gold: False and silver: False.
# Article691 contains gold: False and silver: False.
# Article692 contains gold: False and silver: False.
# Article693 contains gold: False and silver: False.
# Article694 contains gold: False and silver: False.
# Article695 contains gold: False and silver: False.
# Article696 contains gold: False and silver: False.
# Article697 contains gold: False and silver: False.
# Article698 contains gold: False and silver: False.
# Article699 contains gold: False and silver: False.
# Article700 contains gold: False and silver: False.
# Article701 contains gold: False and silver: False.
# Article702 contains gold: False and silver: False.
# Article703 contains gold: False and silver: False.
# Article704 contains gold: False and silver: False.
# Article705 contains gold: False and silver: False.
# Article706 contains gold: False and silver: False.
# Article707 contains gold: False and silver: False.
# Article708 contains gold: False and silver: False.
# Article709 contains gold: False and silver: False.
# Article710 contains gold: False and silver: False.
# Article711 contains gold: False and silver: False.
# Article712 contains gold: False and silver: False.
# Article713 contains gold: False and silver: False.
# Article714 contains gold: False and silver: False.
# Article715 contains gold: False and silver: False.
# Article716 contains gold: False and silver: False.
# Article717 contains gold: False and silver: False.
# Article718 contains gold: False and silver: False.
# Article719 contains gold: False and silver: False.
# Article720 contains gold: False and silver: False.
# Article721 contains gold: False and silver: False.
# Article722 contains gold: False and silver: False.
# Article723 contains gold: True and silver: False.
# Article724 contains gold: False and silver: False.
# Article725 contains gold: False and silver: False.
# Article726 contains gold: False and silver: False.
# Article727 contains gold: False and silver: False.
# Article728 contains gold: False and silver: False.
# Article729 contains gold: False and silver: False.
# Article730 contains gold: False and silver: False.
# Article731 contains gold: False and silver: False.
# Article732 contains gold: False and silver: False.
# Article733 contains gold: False and silver: False.
# Article734 contains gold: False and silver: False.
# Article735 contains gold: False and silver: False.
# Article736 contains gold: False and silver: False.
# Article737 contains gold: False and silver: False.
# Article738 contains gold: False and silver: False.
# Article739 contains gold: False and silver: False.
# Article740 contains gold: False and silver: False.
# Article741 contains gold: False and silver: False.
# Article742 contains gold: False and silver: False.
# Article743 contains gold: False and silver: False.
# Article744 contains gold: False and silver: False.
# Article745 contains gold: False and silver: False.
# Article746 contains gold: False and silver: False.
# Article747 contains gold: False and silver: False.
# Article748 contains gold: False and silver: False.
# Article749 contains gold: False and silver: False.
# Article750 contains gold: False and silver: False.
# Article751 contains gold: False and silver: False.
# Article752 contains gold: False and silver: False.
# Article753 contains gold: False and silver: False.
# Article754 contains gold: False and silver: False.
# Article755 contains gold: False and silver: False.
# Article756 contains gold: False and silver: False.
# Article757 contains gold: False and silver: False.
# Article758 contains gold: False and silver: False.
# Article759 contains gold: False and silver: False.
# Article760 contains gold: False and silver: False.
# Article761 contains gold: False and silver: False.
# Article762 contains gold: False and silver: False.
# Article763 contains gold: False and silver: False.
# Article764 contains gold: False and silver: False.
# Article765 contains gold: False and silver: False.
# Article766 contains gold: False and silver: False.
# Article767 contains gold: False and silver: False.
# Article768 contains gold: False and silver: False.
# Article769 contains gold: False and silver: False.
# Article770 contains gold: False and silver: False.
# Article771 contains gold: False and silver: False.
# Article772 contains gold: False and silver: False.
# Article773 contains gold: False and silver: False.
# Article774 contains gold: False and silver: False.
# Article775 contains gold: False and silver: False.
# Article776 contains gold: False and silver: False.
# Article777 contains gold: False and silver: False.
# Article778 contains gold: False and silver: False.
# Article779 contains gold: False and silver: False.
# Article780 contains gold: False and silver: False.
# Article781 contains gold: False and silver: False.
# Article782 contains gold: False and silver: False.
# Article783 contains gold: False and silver: False.
# Article784 contains gold: False and silver: False.
# Article785 contains gold: False and silver: False.
# Article786 contains gold: False and silver: False.
# Article787 contains gold: False and silver: False.
# Article788 contains gold: False and silver: False.
# Article789 contains gold: False and silver: False.
# Article790 contains gold: False and silver: False.
# Article791 contains gold: False and silver: False.
# Article792 contains gold: False and silver: False.
# Article793 contains gold: False and silver: False.
# Article794 contains gold: False and silver: False.
# Article795 contains gold: False and silver: False.
# Article796 contains gold: False and silver: False.
# Article797 contains gold: False and silver: False.
# Article798 contains gold: False and silver: False.
# Article799 contains gold: False and silver: False.
# Article800 contains gold: False and silver: False.
# Article801 contains gold: False and silver: False.
# Article802 contains gold: False and silver: False.
# Article803 contains gold: False and silver: False.
# Article804 contains gold: False and silver: False.
# Article805 contains gold: False and silver: False.
# Article806 contains gold: False and silver: False.
# Article807 contains gold: False and silver: False.
# Article808 contains gold: False and silver: False.
# Article809 contains gold: False and silver: False.
# Article810 contains gold: False and silver: False.
# Article811 contains gold: False and silver: False.
# Article812 contains gold: False and silver: False.
# Article813 contains gold: False and silver: False.
# Article814 contains gold: False and silver: False.
# Article815 contains gold: False and silver: False.
# Article816 contains gold: False and silver: False.
# Article817 contains gold: False and silver: False.
# Article818 contains gold: False and silver: False.
# Article819 contains gold: False and silver: False.
# Article820 contains gold: False and silver: False.
# Article821 contains gold: False and silver: False.
# Article822 contains gold: False and silver: False.
# Article823 contains gold: False and silver: False.
# Article824 contains gold: False and silver: False.
# Article825 contains gold: False and silver: False.
# Article826 contains gold: True and silver: False.
# Article827 contains gold: False and silver: False.
# Article828 contains gold: True and silver: False.
# Article829 contains gold: False and silver: False.
# Article830 contains gold: True and silver: False.
# Article831 contains gold: False and silver: False.
# Article832 contains gold: False and silver: False.
# Article833 contains gold: False and silver: False.
# Article834 contains gold: False and silver: False.
# Article835 contains gold: False and silver: False.
# Article836 contains gold: False and silver: False.
# Article837 contains gold: False and silver: False.
# Article838 contains gold: False and silver: False.
# Article839 contains gold: False and silver: False.
# Article840 contains gold: False and silver: False.
# Article841 contains gold: False and silver: False.
# Article842 contains gold: False and silver: False.
# Article843 contains gold: False and silver: False.
# Article844 contains gold: False and silver: False.
# Article845 contains gold: False and silver: False.
# Article846 contains gold: False and silver: False.
# Article847 contains gold: False and silver: False.
# Article848 contains gold: False and silver: False.
# Article849 contains gold: True and silver: False.
# Article850 contains gold: True and silver: False.
# Article851 contains gold: True and silver: False.
# Article852 contains gold: True and silver: False.
# Article853 contains gold: True and silver: False.
# Article854 contains gold: True and silver: True.
# Article855 contains gold: True and silver: False.
# Article856 contains gold: True and silver: False.
# Article857 contains gold: True and silver: False.
# Article858 contains gold: True and silver: False.
# Article859 contains gold: False and silver: False.
# Article860 contains gold: False and silver: False.
# Article861 contains gold: False and silver: False.
# Article862 contains gold: False and silver: False.
# Article863 contains gold: False and silver: False.
# Article864 contains gold: False and silver: False.
# Article865 contains gold: False and silver: False.
# Article866 contains gold: False and silver: False.
# Article867 contains gold: False and silver: False.
# Article868 contains gold: False and silver: False.
# Article869 contains gold: False and silver: False.
# Article870 contains gold: False and silver: False.
# Article871 contains gold: False and silver: False.
# Article872 contains gold: False and silver: False.
# Article873 contains gold: False and silver: False.
# Article874 contains gold: False and silver: False.
# Article875 contains gold: False and silver: False.
# Article876 contains gold: False and silver: False.
# Article877 contains gold: False and silver: False.
# Article878 contains gold: False and silver: False.
# Article879 contains gold: False and silver: False.
# Article880 contains gold: False and silver: False.
# Article881 contains gold: False and silver: False.
# Article882 contains gold: False and silver: False.
# Article883 contains gold: False and silver: False.
# Article884 contains gold: False and silver: False.
# Article885 contains gold: False and silver: False.
# Article886 contains gold: False and silver: False.
# Article887 contains gold: False and silver: False.
# Article888 contains gold: False and silver: False.
# Article889 contains gold: False and silver: False.
# Article890 contains gold: False and silver: False.
# Article891 contains gold: False and silver: False.
# Article892 contains gold: False and silver: False.
# Article893 contains gold: False and silver: False.
# Article894 contains gold: False and silver: False.
# Article895 contains gold: False and silver: False.
# Article896 contains gold: False and silver: False.
# Article897 contains gold: False and silver: False.
# Article898 contains gold: False and silver: False.
# Article899 contains gold: False and silver: False.
# Article900 contains gold: False and silver: False.
# Article901 contains gold: False and silver: False.
# Article902 contains gold: False and silver: False.
# Article903 contains gold: False and silver: False.
# Article904 contains gold: False and silver: False.
# Article905 contains gold: True and silver: False.
# Article906 contains gold: False and silver: False.
# Article907 contains gold: True and silver: False.
# Article908 contains gold: False and silver: False.
# Article909 contains gold: True and silver: False.
# Article910 contains gold: False and silver: False.
# Article911 contains gold: False and silver: False.
# Article912 contains gold: False and silver: False.
# Article913 contains gold: False and silver: False.
# Article914 contains gold: False and silver: False.
# Article915 contains gold: False and silver: False.
# Article916 contains gold: False and silver: False.
# Article917 contains gold: False and silver: False.
# Article918 contains gold: False and silver: False.
# Article919 contains gold: False and silver: False.
# Article920 contains gold: False and silver: False.
# Article921 contains gold: False and silver: False.
# Article922 contains gold: False and silver: False.
# Article923 contains gold: False and silver: False.
# Article924 contains gold: False and silver: False.
# Article925 contains gold: False and silver: False.
# Article926 contains gold: False and silver: False.
# Article927 contains gold: False and silver: False.
# Article928 contains gold: False and silver: False.
# Article929 contains gold: False and silver: False.
# Article930 contains gold: False and silver: False.
# Article931 contains gold: False and silver: False.
# Article932 contains gold: False and silver: False.
# Article933 contains gold: False and silver: False.
# Article934 contains gold: False and silver: False.
# Article935 contains gold: False and silver: False.
# Article936 contains gold: False and silver: False.
# Article937 contains gold: False and silver: False.
# Article938 contains gold: False and silver: False.
# Article939 contains gold: False and silver: False.
# Article940 contains gold: False and silver: False.
# Article941 contains gold: False and silver: False.
# Article942 contains gold: False and silver: False.
# Article943 contains gold: False and silver: False.
# Article944 contains gold: False and silver: False.
# Article945 contains gold: False and silver: False.
# Article946 contains gold: False and silver: False.
# Article947 contains gold: False and silver: False.
# Article948 contains gold: False and silver: False.
# Article949 contains gold: False and silver: False.
# Article950 contains gold: False and silver: False.
# ...
# Article1564 contains gold: False and silver: False.
# Article1565 contains gold: False and silver: False.
# Article1566 contains gold: False and silver: False.
# Article1567 contains gold: False and silver: False.
# Article1568 contains gold: False and silver: False.
# Article1569 contains gold: False and silver: False.
# Article1570 contains gold: False and silver: False.
# Article1571 contains gold: False and silver: False.
# Article1572 contains gold: False and silver: False.
# Article1573 contains gold: False and silver: False.
# Article1574 contains gold: False and silver: False.
# Article1575 contains gold: False and silver: False.
# Article1576 contains gold: False and silver: False.
# Article1577 contains gold: False and silver: False.
# Article1578 contains gold: False and silver: False.
# Article1579 contains gold: False and silver: False.
# Article1580 contains gold: False and silver: False.
# Article1581 contains gold: False and silver: False.
# Article1582 contains gold: False and silver: False.
# Article1583 contains gold: False and silver: False.
# Article1584 contains gold: False and silver: False.
# Article1585 contains gold: False and silver: False.
# Article1586 contains gold: False and silver: False.
# Article1587 contains gold: False and silver: False.
# Article1588 contains gold: False and silver: False.
# Article1589 contains gold: False and silver: False.
# Article1590 contains gold: False and silver: False.
# Article1591 contains gold: False and silver: False.
# Article1592 contains gold: False and silver: False.
# Article1593 contains gold: False and silver: False.
# Article1594 contains gold: False and silver: False.
# Article1595 contains gold: False and silver: False.
# Article1596 contains gold: False and silver: False.
# Article1597 contains gold: False and silver: False.
# Article1598 contains gold: False and silver: False.
# Article1599 contains gold: False and silver: False.
# Article1600 contains gold: False and silver: False.
# Article1601 contains gold: False and silver: False.
# Article1602 contains gold: False and silver: False.
# Article1603 contains gold: False and silver: False.
# Article1604 contains gold: False and silver: False.
# Article1605 contains gold: False and silver: False.
# Article1606 contains gold: False and silver: False.
# Article1607 contains gold: False and silver: False.
# Article1608 contains gold: False and silver: False.
# Article1609 contains gold: False and silver: False.
# Article1610 contains gold: False and silver: False.
# Article1611 contains gold: False and silver: False.
# Article1612 contains gold: False and silver: False.
# Article1613 contains gold: False and silver: False.
# Article1614 contains gold: False and silver: False.
# Article1615 contains gold: False and silver: False.
# Article1616 contains gold: False and silver: False.
# Article1617 contains gold: False and silver: False.
# Article1618 contains gold: False and silver: False.
# Article1619 contains gold: False and silver: False.
# Article1620 contains gold: False and silver: False.
# Article1621 contains gold: False and silver: False.
# Article1622 contains gold: False and silver: False.
# Article1623 contains gold: False and silver: False.
# Article1624 contains gold: False and silver: False.
# Article1625 contains gold: False and silver: False.
# Article1626 contains gold: False and silver: False.
# Article1627 contains gold: False and silver: False.
# Article1628 contains gold: False and silver: False.
# Article1629 contains gold: False and silver: False.
# Article1630 contains gold: False and silver: False.
# Article1631 contains gold: False and silver: False.
# Article1632 contains gold: False and silver: False.
# Article1633 contains gold: False and silver: False.
# Article1634 contains gold: False and silver: False.
# Article1635 contains gold: False and silver: False.
# Article1636 contains gold: False and silver: False.
# Article1637 contains gold: False and silver: False.
# Article1638 contains gold: False and silver: False.
# Article1639 contains gold: False and silver: False.
# Article1640 contains gold: False and silver: False.
# Article1641 contains gold: False and silver: False.
# Article1642 contains gold: False and silver: False.
# Article1643 contains gold: False and silver: False.
# Article1644 contains gold: False and silver: False.
# Article1645 contains gold: False and silver: False.
# Article1646 contains gold: False and silver: False.
# Article1647 contains gold: False and silver: False.
# Article1648 contains gold: False and silver: False.
# Article1649 contains gold: False and silver: False.
# Article1650 contains gold: False and silver: False.
# Article1651 contains gold: False and silver: False.
# Article1652 contains gold: False and silver: False.
# Article1653 contains gold: False and silver: False.
# Article1654 contains gold: False and silver: False.
# Article1655 contains gold: False and silver: False.
# Article1656 contains gold: False and silver: False.
# Article1657 contains gold: False and silver: False.
# Article1658 contains gold: False and silver: False.
# Article1659 contains gold: False and silver: False.
# Article1660 contains gold: False and silver: False.
# Article1661 contains gold: False and silver: False.
# Article1662 contains gold: False and silver: False.
# Article1663 contains gold: False and silver: False.
# Article1664 contains gold: False and silver: False.
# Article1665 contains gold: False and silver: False.
# Article1666 contains gold: False and silver: False.
# Article1667 contains gold: False and silver: False.
# Article1668 contains gold: False and silver: False.
# Article1669 contains gold: False and silver: False.
# Article1670 contains gold: False and silver: False.
# Article1671 contains gold: False and silver: False.
# Article1672 contains gold: False and silver: False.
# Article1673 contains gold: False and silver: False.
# Article1674 contains gold: False and silver: False.
# Article1675 contains gold: False and silver: False.
# Article1676 contains gold: False and silver: False.
# Article1677 contains gold: False and silver: False.
# Article1678 contains gold: False and silver: False.
# Article1679 contains gold: False and silver: False.
# Article1680 contains gold: False and silver: False.
# Article1681 contains gold: False and silver: False.
# Article1682 contains gold: False and silver: False.
# Article1683 contains gold: False and silver: False.
# Article1684 contains gold: False and silver: False.
# Article1685 contains gold: False and silver: False.
# Article1686 contains gold: False and silver: False.
# Article1687 contains gold: False and silver: False.
# Article1688 contains gold: False and silver: False.
# Article1689 contains gold: False and silver: False.
# Article1690 contains gold: False and silver: False.
# Article1691 contains gold: False and silver: False.
# Article1692 contains gold: False and silver: False.
# Article1693 contains gold: False and silver: False.
# Article1694 contains gold: False and silver: False.
# Article1695 contains gold: False and silver: False.
# Article1696 contains gold: False and silver: False.
# Article1697 contains gold: False and silver: False.
# Article1698 contains gold: False and silver: False.
# Article1699 contains gold: False and silver: False.
# Article1700 contains gold: False and silver: False.
# Article1701 contains gold: False and silver: False.
# Article1702 contains gold: False and silver: False.
# Article1703 contains gold: False and silver: False.
# Article1704 contains gold: False and silver: False.
# Article1705 contains gold: False and silver: False.
# Article1706 contains gold: False and silver: False.
# Article1707 contains gold: False and silver: False.
# Article1708 contains gold: False and silver: False.
# Article1709 contains gold: False and silver: False.
# Article1710 contains gold: False and silver: False.
# Article1711 contains gold: False and silver: False.
# Article1712 contains gold: False and silver: False.
# Article1713 contains gold: False and silver: False.
# Article1714 contains gold: False and silver: False.
# Article1715 contains gold: False and silver: False.
# Article1716 contains gold: False and silver: False.
# Article1717 contains gold: False and silver: False.
# Article1718 contains gold: False and silver: False.
# Article1719 contains gold: False and silver: False.
# Article1720 contains gold: False and silver: False.
# Article1721 contains gold: False and silver: False.
# Article1722 contains gold: False and silver: False.
# Article1723 contains gold: False and silver: False.
# Article1724 contains gold: False and silver: False.
# Article1725 contains gold: False and silver: False.
# Article1726 contains gold: False and silver: False.
# Article1727 contains gold: False and silver: False.
# Article1728 contains gold: False and silver: False.
# Article1729 contains gold: False and silver: False.
# Article1730 contains gold: False and silver: False.
# Article1731 contains gold: False and silver: False.
# Article1732 contains gold: False and silver: False.
# Article1733 contains gold: False and silver: False.
# Article1734 contains gold: False and silver: False.
# Article1735 contains gold: False and silver: False.
# Article1736 contains gold: False and silver: False.
# Article1737 contains gold: False and silver: False.
# Article1738 contains gold: False and silver: False.
# Article1739 contains gold: False and silver: False.
# Article1740 contains gold: False and silver: False.
# Article1741 contains gold: False and silver: False.
# Article1742 contains gold: False and silver: False.
# Article1743 contains gold: False and silver: False.
# Article1744 contains gold: False and silver: False.
# Article1745 contains gold: False and silver: False.
# Article1746 contains gold: False and silver: False.
# Article1747 contains gold: False and silver: False.
# Article1748 contains gold: False and silver: False.
# Article1749 contains gold: False and silver: False.
# Article1750 contains gold: False and silver: False.
# Article1751 contains gold: False and silver: False.
# Article1752 contains gold: False and silver: False.
# Article1753 contains gold: False and silver: False.
# Article1754 contains gold: False and silver: False.
# Article1755 contains gold: False and silver: False.
# Article1756 contains gold: False and silver: False.
# Article1757 contains gold: False and silver: False.
# Article1758 contains gold: False and silver: False.
# Article1759 contains gold: False and silver: False.
# Article1760 contains gold: False and silver: False.
# Article1761 contains gold: False and silver: False.
# Article1762 contains gold: False and silver: False.
# Article1763 contains gold: False and silver: False.
# Article1764 contains gold: False and silver: False.
# Article1765 contains gold: False and silver: False.
# Article1766 contains gold: False and silver: False.
# Article1767 contains gold: False and silver: False.
# Article1768 contains gold: False and silver: False.
# Article1769 contains gold: False and silver: False.
# Article1770 contains gold: False and silver: False.
# Article1771 contains gold: False and silver: False.
# Article1772 contains gold: False and silver: False.
# Article1773 contains gold: False and silver: False.
# Article1774 contains gold: False and silver: False.
# Article1775 contains gold: False and silver: False.
# Article1776 contains gold: False and silver: False.
# Article1777 contains gold: False and silver: False.
# Article1778 contains gold: False and silver: False.
# Article1779 contains gold: False and silver: False.
# Article1780 contains gold: False and silver: False.
# Article1781 contains gold: False and silver: False.
# Article1782 contains gold: False and silver: False.
# Article1783 contains gold: False and silver: False.
# Article1784 contains gold: False and silver: False.
# Article1785 contains gold: False and silver: False.
# Article1786 contains gold: False and silver: False.
# Article1787 contains gold: False and silver: False.
# Article1788 contains gold: False and silver: False.
# Article1789 contains gold: False and silver: False.
# Article1790 contains gold: False and silver: False.
# Article1791 contains gold: False and silver: False.
# Article1792 contains gold: False and silver: False.
# Article1793 contains gold: False and silver: False.
# Article1794 contains gold: False and silver: False.
# Article1795 contains gold: False and silver: False.
# Article1796 contains gold: False and silver: False.
# Article1797 contains gold: False and silver: False.
# Article1798 contains gold: False and silver: False.
# Article1799 contains gold: False and silver: False.
# Article1800 contains gold: False and silver: False.
# Article1801 contains gold: False and silver: False.
# Article1802 contains gold: False and silver: False.
# Article1803 contains gold: False and silver: False.
# Article1804 contains gold: False and silver: False.
# Article1805 contains gold: False and silver: False.
# Article1806 contains gold: False and silver: False.
# Article1807 contains gold: False and silver: False.
# Article1808 contains gold: False and silver: False.
# Article1809 contains gold: False and silver: False.
# Article1810 contains gold: False and silver: False.
# Article1811 contains gold: False and silver: False.
# Article1812 contains gold: False and silver: False.
# Article1813 contains gold: False and silver: False.
# Article1814 contains gold: False and silver: False.
# Article1815 contains gold: False and silver: False.
# Article1816 contains gold: False and silver: False.
# Article1817 contains gold: False and silver: False.
# Article1818 contains gold: False and silver: False.
# Article1819 contains gold: False and silver: False.
# Article1820 contains gold: False and silver: False.
# Article1821 contains gold: False and silver: False.
# Article1822 contains gold: False and silver: False.
# Article1823 contains gold: False and silver: False.
# Article1824 contains gold: False and silver: False.
# Article1825 contains gold: False and silver: False.
# Article1826 contains gold: False and silver: False.
# Article1827 contains gold: False and silver: False.
# Article1828 contains gold: False and silver: False.
# Article1829 contains gold: False and silver: False.
# Article1830 contains gold: False and silver: False.
# Article1831 contains gold: False and silver: False.
# Article1832 contains gold: False and silver: False.
# Article1833 contains gold: False and silver: False.
# Article1834 contains gold: False and silver: False.
# Article1835 contains gold: False and silver: False.
# Article1836 contains gold: False and silver: False.
# Article1837 contains gold: False and silver: False.
# Article1838 contains gold: False and silver: False.
# Article1839 contains gold: False and silver: False.
# Article1840 contains gold: False and silver: False.
# Article1841 contains gold: False and silver: False.
# Article1842 contains gold: False and silver: False.
# Article1843 contains gold: False and silver: False.
# Article1844 contains gold: False and silver: False.
# Article1845 contains gold: False and silver: False.
# Article1846 contains gold: False and silver: False.
# Article1847 contains gold: False and silver: False.
# Article1848 contains gold: False and silver: False.
# Article1849 contains gold: False and silver: False.
# Article1850 contains gold: False and silver: False.
# Article1851 contains gold: False and silver: False.
# Article1852 contains gold: False and silver: False.
# Article1853 contains gold: False and silver: False.
# Article1854 contains gold: False and silver: False.
# Article1855 contains gold: False and silver: False.
# Article1856 contains gold: False and silver: False.
# Article1857 contains gold: False and silver: False.
# Article1858 contains gold: False and silver: False.
# Article1859 contains gold: False and silver: False.
# Article1860 contains gold: False and silver: False.
# Article1861 contains gold: False and silver: False.
# Article1862 contains gold: False and silver: False.
# Article1863 contains gold: False and silver: False.
# Article1864 contains gold: False and silver: False.
# Article1865 contains gold: False and silver: False.
# Article1866 contains gold: False and silver: False.
# Article1867 contains gold: False and silver: False.
# Article1868 contains gold: False and silver: False.
# Article1869 contains gold: False and silver: False.
# Total articles containing gold: 691
# Total articles containing silver: 109

# %% [markdown]
# By looking at the result, it seems many articles contains gold or silver.

# %% [markdown]
# ##### Task3: Further excluding any misleading content with gold/silver

# %%
# Create dictionary of context-specific conditions
false_positives = {
    "gold": ["gold standard", "goldilocks"],
    "silver": ["silver lining"]
}

import string 

# Find 'gold' & 'silver' with context-specific checks
def string_matcher(article):
    article_lower = article.lower()
    contains_gold = False
    contains_silver = False
    gold_matched_terms_list = [] # list to store matched terms
    silver_matched_terms_list = [] # list to store matched terms

    # Check for "gold" with context-specific conditions
    if "gold" in article_lower:
        if any(phrase in article_lower for phrase in false_positives["gold"]):
            contains_gold = False
        else:
            contains_gold = True
            matched_terms = [term for term in article_lower.split() if term != "gold" and "gold" in term 
                                                                            and term not in false_positives["gold"]
                                                                            and not term.startswith(tuple(string.punctuation))
                                                                            and not term.endswith(tuple(string.punctuation))]
            gold_matched_terms_list.extend(matched_terms)

    # Check for "silver" with context-specific conditions
    if "silver" in article_lower:
        if any(phrase in article_lower for phrase in false_positives["silver"]):
            contains_silver = False
        else:
            contains_silver = True
            matched_terms = [term for term in article_lower.split() if term != "silver" and "silver" in term 
                                                                            and term not in false_positives["silver"]
                                                                            and not term.startswith(tuple(string.punctuation))
                                                                            and not term.endswith(tuple(string.punctuation))]
            silver_matched_terms_list.extend(matched_terms)

    return contains_gold, contains_silver, gold_matched_terms_list, silver_matched_terms_list


gold_count = 0
silver_count = 0

for i, text in enumerate(articles):
    contains_gold, contains_silver, gold_matched_terms_list, silver_matched_terms_list = string_matcher(text)
#     print(f'Article{i} contains gold: {contains_gold} and silver: {contains_silver}.')
    if contains_gold:
        gold_count += 1
        false_positives["gold"].extend(gold_matched_terms_list)

    if contains_silver:
        silver_count += 1
        false_positives["silver"].extend(silver_matched_terms_list)

print(f'Total articles containing gold: {gold_count}')
print(f'Total articles containing silver: {silver_count}')
print(f'Updated false positives for gold: {false_positives["gold"]}')
print(f'Updated false positives for silver: {false_positives["silver"]}')
# Out:
# Total articles containing gold: 596
# Total articles containing silver: 102
# Updated false positives for gold: ['gold standard', 'goldilocks', "gold's", 'anglogold', 'anglogold', 'ashgold', 'randgold', 'golden', 'goldman', 'gold/copper', 'gold-plated', '23.0275.gold', 'goldsmith', '“gold-tinted', '24kgoldn', 'https://www.theaustralian.com.au/business/dgo-gold-aiming-to-strike-a-balance-in-gold-exploration/news-story/231d9ce048bfd7d7f87545741008db15dgo', '“gold', 'australia.“gold', 'gold’s', 'gold.dgo', 'golder', 'discovergold', 'goldmine', 'https://www.theedgesingapore.com/capital/investing-ideas/rotate-back-technology-stocks-gold-says-dbs', '1.9%.gold', 'goldsbury', 'goldsbury', 'goldsbury', 'goldfarming', 'gold-backed', 'https://www.history.com/this-day-in-history/fdr-takes-united-states-off-gold-standard', 'goldberg', 'gold--in', 'goldwyn', 'goldwyns', 'goldstein', 'added.gold', "snip.http://www.cratergold.com.au/irm/content/polymetallic-project.aspx?rid=310&redirectcount=1they've", 'gold/silver']
# Updated false positives for silver: ['silver lining', 'silverware', 'silverwater', 'silverwater', 'silverwater', 'silverwater', 'silvertown', 'info@reynasilver.com', 'www.reynasilver.com', 'silver’s', 'silver…', 'silverado', 'silvery', 'silvery', 'silverlink', 'benefits.silver', 'silverash', '“silver', '“silver', 'gold/silver']

# %%
# Out:
# []
